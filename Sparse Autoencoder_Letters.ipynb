# %% [markdown]
# # **Sparse Autoencoder**

# %%
# import libraries

import os.path
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import tensorflow as tf
import matplotlib.pyplot as plt

import keras
from keras.layers import Input, Dense, Lambda, Reshape
from keras.models import Model
from keras import backend as K
from keras import metrics
from keras.datasets import mnist
from keras import regularizers

# %%
# defining the key parameters
batch_size = 100
original_dim = 784 # x: 28x28
latent_dim = 2 # z
intermediate_dim = 256 # h
epochs = 50

# %%
print(f'tensorflow version = {tf.__version__}')
print(f'keras version = {keras.__version__}')

# Countermeasures for version inconsistencies
tf.compat.v1.disable_eager_execution()
# Out:
# tensorflow version = 2.7.0
# keras version = 2.7.0

# %% [markdown]
# **Defining the encoder**

# %%
# input to our encoder
x = Input(shape=(original_dim,), name="input")
# intermediate layer (hidden layer 1)
h = Dense(intermediate_dim, activation='relu', activity_regularizer=regularizers.l1(10e-6), name="encoding")(x)
# defining the mean of the latent space (code layer)
z = Dense(latent_dim, activity_regularizer=regularizers.l1(10e-6), name="z")(h)

# define and print out summary of the encoder
encoder = Model(x, z, name="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  encoding (Dense)            (None, 256)               200960
#
#  z (Dense)                   (None, 2)                 514
#
# =================================================================
# Total params: 201,474
# Trainable params: 201,474
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Defining the decoder**

# %%
# Input to the decoder
input_decoder = Input(shape=(latent_dim,), name="decoder_input")
# taking the latent space to intermediate dimension (hidden layer 2)
decoder_h = Dense(intermediate_dim, activation='relu', name="decoder_h")(input_decoder)
# getting the mean from the original dimension
x_decoded = Dense(original_dim, activation='sigmoid', name="flat_decoded")(decoder_h)

# # define and print out summary of the decoder
decoder = Model(input_decoder, x_decoded, name="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  decoder_input (InputLayer)  [(None, 2)]               0
#
#  decoder_h (Dense)           (None, 256)               768
#
#  flat_decoded (Dense)        (None, 784)               201488
#
# =================================================================
# Total params: 202,256
# Trainable params: 202,256
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Definition of the AE: Combining the encoder and the decoder**

# %%
# Combining the encoder and decoder.

output_combined = decoder(encoder(x))
# link the input and the overall output
AE = Model(x, output_combined)
# print out what the overall model looks like
AE.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  encoder (Functional)        (None, 2)                 201474
#
#  decoder (Functional)        (None, 784)               202256
#
# =================================================================
# Total params: 403,730
# Trainable params: 403,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Definition of the loss function**
#
# Total loss is the binary-cross-entropy (BCE) loss (as a reconstruction error)
#
# $L_{total}=L_{BCE}$
#
# In BCE loss, each pixel value is consedered as a probability

# %%
def AE_loss(x: tf.Tensor, x_decoded_mean: tf.Tensor, 
            original_dim=original_dim):
    BCE_loss = original_dim * metrics.binary_crossentropy(x, x_decoded_mean)
    AE_loss = K.mean(BCE_loss)
    return AE_loss

AE.compile(optimizer='rmsprop', loss=AE_loss)
AE.summary()
# Out:
# Model: "model_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 784)]             0
#
#  encoder (Functional)        (None, 2)                 201474
#
#  decoder (Functional)        (None, 784)               202256
#
# =================================================================
# Total params: 403,730
# Trainable params: 403,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Loading MNIST dataset**

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %% [markdown]
# **Chek the data size and contents**

# %%
print(f'x_train.shape {x_train.shape}')
print(f'x_test.shape {x_test.shape}')
print(f'y_train.shape {y_train.shape}')
print(f'y_test.shape {y_test.shape}')
# Out:
# x_train.shape (60000, 784)
# x_test.shape (10000, 784)
# y_train.shape (60000,)
# y_test.shape (10000,)

# %%
# display MNIST data
W = 10  # number of images in width
H = 5   # number of images in height
fig = plt.figure(figsize=(H, W))
fig.subplots_adjust(left=0, right=1, bottom=0,
                    top=0.3, hspace=0.10, wspace=0.10)
for i in range(W*H):
    ax = fig.add_subplot(H, W, i + 1, xticks=[], yticks=[])
    ax.imshow(x_train[i].reshape(28,-1), cmap='gray')

plt.show()
#print(F'x_train {x_train[0:10][0:10]}')
print(F'y_train={y_train[0:W*H]}')
# Out:
# y_train=[5 0 4 1 9 2 1 3 1 4 3 5 3 6 1 7 2 8 6 9 4 0 9 1 1 2 4 3 2 7 3 8 6 9 0 5 6
#  0 7 6 1 8 7 9 3 9 8 5 9 3]

# %% [markdown]
# ## ***Visualize the digits***

# %%
def show_data(X, n=10, height=28, width=28, title=""):
    plt.figure(figsize=(10, 3))
    for i in range(n):
        ax = plt.subplot(2,n,i+1)
        plt.imshow(X[i].reshape((height,width)))
        plt.gray()
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.suptitle(title, fontsize = 20)

# %%
show_data(x_train, title="train data")
show_data(x_test, title="test data")

# %% [markdown]
# **Train the Autoencoder**

# %%
AE.fit(x_train, x_train,
        shuffle=True,
        epochs=epochs, 
        batch_size=batch_size)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 9s 142us/sample - loss: 179.1479
# Epoch 2/50
# 60000/60000 [==============================] - 8s 136us/sample - loss: 159.9501
# Epoch 3/50
# 60000/60000 [==============================] - 8s 136us/sample - loss: 156.3669
# Epoch 4/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 153.8534
# Epoch 5/50
# 60000/60000 [==============================] - 8s 135us/sample - loss: 151.8962
# Epoch 6/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 150.5155
# Epoch 7/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 149.4775
# Epoch 8/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 148.6668
# Epoch 9/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 147.9759
# Epoch 10/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 147.3898
# Epoch 11/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 146.8855
# Epoch 12/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 146.3987
# Epoch 13/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 146.0022
# Epoch 14/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 145.6190
# Epoch 15/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 145.2660
# Epoch 16/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 144.9533
# Epoch 17/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 144.6451
# Epoch 18/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 144.3460
# Epoch 19/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 144.0691
# Epoch 20/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 143.8244
# Epoch 21/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 143.5415
# Epoch 22/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 143.2759
# Epoch 23/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 143.0489
# Epoch 24/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 142.8243
# Epoch 25/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 142.5699
# Epoch 26/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 142.3662
# Epoch 27/50
# 60000/60000 [==============================] - 8s 135us/sample - loss: 142.1808
# Epoch 28/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 141.9929
# Epoch 29/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 141.8007
# Epoch 30/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 141.6240
# Epoch 31/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 141.4641
# Epoch 32/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 141.2909
# Epoch 33/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 141.1667
# Epoch 34/50
# 60000/60000 [==============================] - 8s 135us/sample - loss: 141.0180
# Epoch 35/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 140.8788
# Epoch 36/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 140.7595
# Epoch 37/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 140.6277
# Epoch 38/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 140.4871
# Epoch 39/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 140.3827
# Epoch 40/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 140.2473
# Epoch 41/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 140.1770
# Epoch 42/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 140.0348
# Epoch 43/50
# 60000/60000 [==============================] - 8s 128us/sample - loss: 139.9627
# Epoch 44/50
# 60000/60000 [==============================] - 8s 129us/sample - loss: 139.8577
# Epoch 45/50
# 60000/60000 [==============================] - 8s 130us/sample - loss: 139.7513
# Epoch 46/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 139.6694
# Epoch 47/50
# 60000/60000 [==============================] - 8s 132us/sample - loss: 139.5877
# Epoch 48/50
# 60000/60000 [==============================] - 8s 131us/sample - loss: 139.5066
# Epoch 49/50
# 60000/60000 [==============================] - 8s 133us/sample - loss: 139.4025
# Epoch 50/50
# 60000/60000 [==============================] - 8s 134us/sample - loss: 139.3164

# %% [markdown]
# **Check the distribution of x_test in the latent feature space (z: 2dim)**
#
# We can see the distibution of 2D embedding (z).\ We can see that the same numbers are distributed close together.

# %% [markdown]
# **784dim of the input information is compressed to only 2dim!**

# %%
# display a 2D plot of the digit classes in the latent space (first 2dim)
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:,0], x_test_encoded[:,1], c=y_test, cmap='jet')
plt.colorbar()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %% [markdown]
# **Let us see the reconstructed images from the latent space**

# %%
# display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

# change the range of visialization according to the above results. 
grid_y = np.linspace(-10, 50, n)
grid_x = np.linspace(-20, 20, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()

# %% [markdown]
# **Get the decoded (reconstructed data)**

# %%
decoded_data = AE.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %% [markdown]
# **Make a model to get the encoded representation (i.e. intermediate layer output for a given input)**
#
# Making the half model of our actual model
#
# The input = our acutal model input
#
# The output = code layer "z" (see enconder)

# %%
get_encoded_data = Model(inputs = AE.input, outputs = AE.get_layer("encoder").outputs)

# %% [markdown]
# **Get the encoded data**

# %%
encoded_data = get_encoded_data.predict (x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %% [markdown]
# **Visualize the results on test set**

# %%
show_data(x_test, title = "original test data")
show_data(encoded_data, height =1, width=2, title = "encoded test data")
show_data(decoded_data, title="decoded test data")

# %% [markdown]
# # **Visualizing weights and bias from different layers**

# %%
encoder.layers[2].get_weights()
# Out:
# [array([[ 2.77635366e-01,  1.19618702e+00],
#         [-4.02776524e-02,  1.49192005e-01],
#         [-9.49909762e-02, -2.35737085e-01],
#         [ 1.47019252e-01,  6.03570998e-01],
#         [-3.66785228e-02,  1.20563634e-01],
#         [ 4.03140068e-01,  4.33464617e-01],
#         [ 2.89878535e+00,  5.42023480e-01],
#         [-2.20395252e-01,  1.02937472e+00],
#         [-1.86389908e-01, -3.96412104e-01],
#         [-3.25197093e-02, -5.93037046e-02],
#         [-1.36183381e-01, -8.14428478e-02],
#         [-3.78997698e-02, -3.30766030e-02],
#         [ 1.91540569e-02,  5.27783453e-01],
#         [ 5.47384119e+00, -1.10487625e-01],
#         [-1.26079768e-01,  1.46313310e-01],
#         [-4.48022246e-01, -5.38153611e-02],
#         [-1.06868729e-01, -3.29237767e-02],
#         [ 1.08843851e+00, -8.59155416e-01],
#         [ 6.03485964e-02, -7.28913024e-02],
#         [-8.43183324e-02, -3.03697437e-01],
#         [ 5.46588888e-03,  6.23283803e-01],
#         [ 1.20788622e+00, -1.58454940e-01],
#         [ 2.41754150e+00, -6.12840056e-01],
#         [ 1.31194860e-01, -6.22248292e-01],
#         [-1.13479212e-01,  5.86659759e-02],
#         [-9.28848460e-02, -1.13563240e+00],
#         [-1.86951667e-01,  6.82926476e-01],
#         [-1.01672329e-01, -2.53286120e-02],
#         [ 1.29616749e+00, -9.74777937e-01],
#         [ 8.71909678e-01, -4.97424036e-01],
#         [ 1.39066309e-01, -2.86917631e-02],
#         [-6.12303689e-02,  1.33274794e-01],
#         [-1.14153907e-01, -3.04466095e-02],
#         [-4.71771389e-01,  5.79576433e-01],
#         [-2.96615154e-01,  2.32401222e-01],
#         [ 6.11134917e-02, -5.79919890e-02],
#         [-2.53684640e-01, -2.97898859e-01],
#         [ 4.60488051e-01, -8.68120372e-01],
#         [ 1.83651909e-01, -5.20100296e-01],
#         [-2.01221302e-01, -2.88593560e-01],
#         [-1.00399561e-01,  6.41935095e-02],
#         [ 1.30959558e+00,  7.91355550e-01],
#         [-4.40632291e-02, -1.30971953e-01],
#         [ 3.05491477e-01,  4.30272847e-01],
#         [ 1.27978638e-01,  3.89192402e-01],
#         [-1.03534333e-01, -1.71497136e-01],
#         [ 3.75829488e-01,  2.48098537e-01],
#         [-5.15616499e-02,  5.33256792e-02],
#         [ 6.03768885e-01,  8.08682203e-01],
#         [-1.18099041e-01,  1.50800049e-01],
#         [ 2.79320478e-01,  3.29091400e-01],
#         [-1.08214989e-01,  6.66270927e-02],
#         [-2.89513826e-01, -4.63542789e-01],
#         [ 7.06732869e-01,  7.51569152e-01],
#         [ 5.54268599e-01,  5.50451040e-01],
#         [-2.47683182e-01,  5.15955091e-01],
#         [ 1.31692457e+00, -6.57873869e-01],
#         [ 1.37203619e-01,  3.78314555e-01],
#         [-4.04224023e-02,  8.07445589e-03],
#         [ 2.80391717e+00,  3.37319165e-01],
#         [ 1.08981222e-01,  1.54512152e-01],
#         [ 5.74312568e-01,  5.26944995e-01],
#         [ 6.07344247e-02, -7.59718657e-01],
#         [ 9.08872545e-01, -1.56368047e-01],
#         [ 2.37705564e+00,  4.13836837e-01],
#         [ 2.53726983e+00,  2.19687819e-01],
#         [-1.08584806e-01, -1.13795966e-01],
#         [ 7.69465089e-01, -7.00483739e-01],
#         [ 2.96126425e-01,  2.22181857e-01],
#         [ 4.58960123e-02,  7.39201784e-01],
#         [ 2.56580210e+00, -5.61970435e-02],
#         [-9.86821204e-02, -9.08757001e-03],
#         [ 9.24518928e-02,  9.50781345e-01],
#         [-3.48683111e-02, -6.63617849e-02],
#         [ 4.88712996e-01, -8.85001123e-01],
#         [ 2.98550487e-01,  1.63677439e-01],
#         [ 9.39895809e-02,  8.60156476e-01],
#         [ 1.61795184e-01,  1.20943196e-01],
#         [ 4.08144188e+00,  5.74052274e-01],
#         [ 3.23641109e+00,  8.94067064e-02],
#         [ 1.88775279e-03, -1.94680467e-01],
#         [-3.83817665e-02,  2.88338643e-02],
#         [-7.26966560e-02, -7.56118968e-02],
#         [-1.24699987e-01,  5.12501113e-02],
#         [ 5.26592016e-01,  3.74786496e-01],
#         [-2.85042107e-01,  4.09081787e-01],
#         [ 5.30696288e-02, -2.05789015e-01],
#         [ 6.72053576e-01, -6.16973698e-01],
#         [-6.08329698e-02,  1.01091139e-01],
#         [-7.69438520e-02, -7.15973368e-03],
#         [ 6.35557622e-02,  1.05900669e+00],
#         [-3.49028632e-02,  1.98978395e-03],
#         [ 3.88942622e-02,  2.31443003e-01],
#         [-3.93978432e-02,  1.43145714e-02],
#         [ 3.33653003e-01,  2.73887992e-01],
#         [-5.03076836e-02,  5.83495572e-03],
#         [ 5.08885801e-01, -6.61531806e-01],
#         [-1.14411809e-01,  1.04287229e-01],
#         [-1.48294255e-01, -2.92899460e-01],
#         [-9.72521082e-02, -1.41687438e-01],
#         [-8.41706932e-01,  8.48153606e-02],
#         [ 8.30097139e-01, -7.34198451e-01],
#         [-7.05876574e-02, -1.33807305e-02],
#         [-7.70495534e-02, -1.54616982e-01],
#         [ 9.16845441e-01,  7.16346204e-01],
#         [ 1.41197085e-01,  1.67201117e-01],
#         [-9.55999568e-02, -3.71604025e-01],
#         [ 1.05582130e+00,  7.58493066e-01],
#         [ 3.98463011e-01,  5.25595844e-01],
#         [-6.65324256e-02,  1.03174970e-01],
#         [-3.34182292e-01,  7.43072331e-01],
#         [ 1.93405766e-02, -3.42323005e-01],
#         [ 2.33976111e-01, -1.36095792e-01],
#         [ 3.29350442e-01,  5.22334218e-01],
#         [-3.08030427e-01, -4.50869203e-01],
#         [ 2.92750621e+00,  3.27266484e-01],
#         [ 3.99277627e-01,  2.00044930e-01],
#         [ 6.74573004e-01, -9.25677776e-01],
#         [ 4.65967447e-01,  5.56708097e-01],
#         [-3.87393758e-02, -4.15789783e-02],
#         [-4.05091457e-02, -2.48286337e-01],
#         [-6.40039518e-02,  4.90261465e-02],
#         [ 2.69175029e+00, -1.54752553e-01]], dtype=float32),
#  array([-0.09796195, -0.19679017], dtype=float32)]

# %%
encoder.layers[2].output.get_shape()
# Out:
# TensorShape([None, 2])

# %%
list(map(lambda x: x.name, encoder.layers))
# Out:
# ['input', 'encoding', 'z']

# %%
intermediate_output = tf.keras.Model(encoder.input, 
                                     encoder.get_layer('encoding').output)
extracted = intermediate_output(x_train[None,:])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 784) for input Tensor("input:0", shape=(None, 784), dtype=float32), but it was called on an input with incompatible shape (1, 60000, 784).
